# %% [markdown]
# #### Consulta en last.fm API

# %% [markdown]
# Librerias

# %%
import requests
import json
import pandas as pd
import time

# %% [markdown]
# Universo bajo : 30 artistas, se consulta a la API last.fm biografia, estadisticas y artistas similares.

# %%
lista_artistas=[
 
    # 🇺🇸 EEUU (10)
    "Taylor Swift", "Drake", "Morgan Wallen", "Kendrick Lamar", "The Weeknd",
    "SZA", "Zach Bryan", "Tyler the Creator", "Billie Eilish", "Ariana Grande",
 
    # 🇪🇸 España (10)
    "Bad Bunny", "Karol G", "Myke Towers", "Quevedo", "Aitana",
    "Rosalía", "Morad", "Melendi", "Enrique Iglesias", "Juanes",
 
    # 🇦🇷 Argentina (10)
    "Duki", "María Becerra", "Tini Stoessel", "Nicki Nicole", "Cazzu",
    "Lali", "Paulo Londra", "Shakira", "Bizarrap", "Emilia",
]
 
print(f"Total: {len(lista_artistas)} artistas ✅")

# %% [markdown]
# API Key

# %%
apikey= "48703fdebfcfe72db0d901a30cf4af31"

# %% [markdown]
# #### Consulta preliminar:
# Biografía del Artista. Popularidad y Estadísticas de Reproducción. Artistas Similares.

# %%
def consulta_info_artista():    #consulta de biografias, campo completo, -not 'summary'
    
    apikey= "48703fdebfcfe72db0d901a30cf4af31"
    
    lista_artistas=["Taylor Swift", "Drake", "Morgan Wallen", "Kendrick Lamar", "The Weeknd",
    "SZA", "Zach Bryan", "Tyler the Creator", "Billie Eilish", "Ariana Grande", "Bad Bunny", 
    "Karol G", "Myke Towers", "Quevedo", "Aitana","Rosalía", "Morad", "Melendi", "Enrique Iglesias",
    "Juanes", "Duki", "María Becerra", "Tini Stoessel", "Nicki Nicole", "Cazzu","Lali", 
    "Paulo Londra", "Shakira", "Bizarrap", "Emilia"]
    
    datos=[]

    for artista in lista_artistas:
        url=f"https://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist={artista}&api_key={apikey}&format=json"
        respuesta=requests.get(url)
        respuesta.status_code

        if respuesta.status_code != 200:
            print (f"Error al consultar {artista}: {respuesta.status_code}.")
        
        info_artista=respuesta.json()
        datos.append({'artista': artista, 'biografia': info_artista['artist']['bio']['content']})
        

    return datos

# %%
bio=consulta_info_artista()

# %%
df_bio=pd.DataFrame(bio)
df_bio.head(5)

# %% [markdown]
# 'artist' {'similar':{'artist':[{name:'sabrina'},...}, {'name: 'taylor'}]}......},{},.. //
# 'bio' -> 'summary' o 'content'
# 'tags' -->{'tag':[{'name': 'pop', 'url': 'https://www.last.fm/tag/pop'},
#      {'name': 'female vocalists',
#       'url': 'https://www.last.fm/tag/female+vocalists'},
#      {'name': 'swedish', 'url': 'https://www.last.fm/tag/swedish'},
#      {'name': '90s', 'url': 'https://www.last.fm/tag/90s'},
#      {'name': 'argentina', 'url': 'https://www.last.fm/tag/argentina'}]},
#    'bio': {'links': {'link': {'#text': '', 'rel': 'original',
#       'href': 'https://last.fm/music/Emilia/+wiki'}},
#     'published': '11 Aug 2006, 21:27',
#     'summary': 'María Emilia Mernes, better known as Emilia, is an Argentine singer, actress and model born on October 29, 1996 in the town of Nogoyá, Entre Ríos.\n\nFrom a very young age she showed a great interest in music, participating in local events and contests. In 2016, Emilia, along with Fer Vázquez, joined the Uruguayan cumbia pop group, Rombai, thus making a place for herself on the scene. She decided in 2018 to leave the group to launch her solo career. <a href="https://www.last.fm/music/Emilia">Read more on Last.fm</a>',
#     'content':María Emilia Mernes, better known as Emilia, is an Argentine singer, actress and model born on October 29, 1996 in the town of Nogoyá, Entre Ríos.\n\nFrom a very young age she showed a great interest in music, participating in local events and contests. In 2016, Emilia, along with Fer Vázquez, joined the Uruguayan cumbia pop group, Rombai, thus making .....SIGUE SIGUE
#     }}}]

# %%
def consulta_stats_artista():
    
    apikey= "48703fdebfcfe72db0d901a30cf4af31"
    
    lista_artistas=["Taylor Swift", "Drake", "Morgan Wallen", "Kendrick Lamar", "The Weeknd",
    "SZA", "Zach Bryan", "Tyler the Creator", "Billie Eilish", "Ariana Grande", "Bad Bunny", 
    "Karol G", "Myke Towers", "Quevedo", "Aitana","Rosalía", "Morad", "Melendi", "Enrique Iglesias",
    "Juanes", "Duki", "María Becerra", "Tini Stoessel", "Nicki Nicole", "Cazzu","Lali", 
    "Paulo Londra", "Shakira", "Bizarrap", "Emilia"]
    
    datos=[]

    for artista in lista_artistas:
        url=f"https://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist={artista}&api_key={apikey}&format=json"
        respuesta=requests.get(url)
        respuesta.status_code

        if respuesta.status_code != 200:
            print (f"Error al consultar {artista}: {respuesta.status_code}.")
        
        info_artista=respuesta.json()
        datos.append({'artista': artista, 'n_oyentes': info_artista['artist']['stats']['listeners'], 'n_playcount': info_artista['artist']['stats']['playcount']})
        

    return datos

# %%
stats=consulta_stats_artista()

# %%
df_stats=pd.DataFrame(stats)
df_stats.head(5)

# %%
df_stats.to_csv('artistas_stats.csv',index=False)

# %%
def consulta_similar_artista():
    
    apikey= "48703fdebfcfe72db0d901a30cf4af31"
    
    lista_artistas=["Taylor Swift", "Drake", "Morgan Wallen", "Kendrick Lamar", "The Weeknd",
    "SZA", "Zach Bryan", "Tyler the Creator", "Billie Eilish", "Ariana Grande", "Bad Bunny", 
    "Karol G", "Myke Towers", "Quevedo", "Aitana","Rosalía", "Morad", "Melendi", "Enrique Iglesias",
    "Juanes", "Duki", "María Becerra", "Tini Stoessel", "Nicki Nicole", "Cazzu","Lali", 
    "Paulo Londra", "Shakira", "Bizarrap", "Emilia"]
    
    datos=[]

    for artista in lista_artistas:
        url=f"https://ws.audioscrobbler.com/2.0/?method=artist.getsimilar&artist={artista}&api_key={apikey}&format=json"
        respuesta=requests.get(url)
        respuesta.status_code

        if respuesta.status_code != 200:
            print (f"Error al consultar {artista}: {respuesta.status_code}.")
        
        info_artista=respuesta.json()

        similares = info_artista.get("similarartists", {}).get("artist", [])

        for similar in similares:
            datos.append({"artista": artista, "similar": similar.get("name")})


    return datos

# %%
similar_artistas=consulta_similar_artista()

# %%
df_similar_artistas=pd.DataFrame(similar_artistas)
df_similar_artistas.head(5)

# %%
df_similar_artistas.to_csv('artistas_similares.csv',index=False)

# %% [markdown]
# #### Consulta de Top artist

# %%
def consulta_top_artistas():
    
    try:
        datos=[]
        apikey= "48703fdebfcfe72db0d901a30cf4af31"
        country=['spain', 'argentina', 'united states']
        
        for pais in country:
            url=f"https://ws.audioscrobbler.com/2.0/?method=geo.gettopartists&country={pais}&api_key={apikey}&format=json"
            respuesta=requests.get(url)
            respuesta.status_code

            if respuesta.status_code != 200:
                print(f"Error al consultar {country}: {respuesta.status_code}")
                continue
            
            info_top_artistas=respuesta.json()
            datos.append(info_top_artistas)
        return datos
    
    except Exception as e:
        print(f"Error: {e}")
        return []

# %%
ranking_top=consulta_top_artistas()

# %%
print(ranking_top)
# Out:
# [{'topartists': {'artist': [{'name': 'Bad Bunny', 'listeners': '12431', 'mbid': '89aa5ecb-59ad-46f5-b3eb-2d424e941f19', 'url': 'https://www.last.fm/music/Bad+Bunny', 'streamable': '0', 'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'small'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'medium'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'large'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'extralarge'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'mega'}], '@attr': {'rank': '1'}}, {'name': 'ROSALÍA', 'listeners': '10254', 'mbid': '25f3abd9-63b5-471a-bd25-feb9672dfa11', 'url': 'https://www.last.fm/music/ROSAL%C3%8DA', 'streamable': '0', 'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'small'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'medium'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'large'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'extralarge'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'mega'}], '@attr': {'rank': '2'}}, {'name': 'Quevedo', 'listeners': '8637', 'mbid': 'ef9bb29f-f466-4e28-8064-32558f4bb2df', 'url': 'https://www.last.fm/music/Quevedo', 'streamable': '0', 'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'small'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'medium'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'large'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'extralarge'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'mega'}], '@attr': {'rank': '3'}}, {'name': 'Justin Bieber', 'listeners': '8379', 'mbid': 'e0140a67-e4d1-4f13-8a01-364355bee46e', 'url': 'https://www.last.fm/music/Justin+Bieber', 'streamable': '0', 'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'small'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'medium'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'large'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'extralarge'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'mega'}], '@attr': {'rank': '4'}}, {'name': 'Olivia Rodrigo', 'listeners': '8227', 'mbid': '6925db17-f35e-42f3-a4eb-84ee6bf5d4b0', 'url': 'https://www.last.fm/music/Olivia+Rodrigo', 'streamable': '0', 'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'small'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'medium'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'large'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'extralarge'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'mega'}], '@attr': {'rank': '5'}}, {'name': 'Taylor Swift', 'listeners': '8191', 'mbid': '20244d07-534f-4eff-b4d4-930878889970', 'url': 'https://www.last.fm/music/Taylor+Swift', 'streamable': '0', 'image': [{'# ...

# %%
ranking_top[0].keys()
# Out:
# dict_keys(['topartists', 'artist'])

# %%
ranking_top[0]['topartists'].keys()
# Out:
# dict_keys(['artist', '@attr'])

# %%
ranking_top[0]['topartists']['artist'][0].keys()
# Out:
# dict_keys(['name', 'listeners', 'mbid', 'url', 'streamable', 'image', '@attr'])

# %%
ranking_top[0]['topartists']['artist'][0].keys()
# Out:
# dict_keys(['name', 'listeners', 'mbid', 'url', 'streamable', 'image', '@attr'])

# %% [markdown]
# #### Confección de datos y DF

# %%
def consulta_top_artistas():
    
    try:
        datos=[]
        apikey= "48703fdebfcfe72db0d901a30cf4af31"
        country=['spain', 'argentina', 'united states']
        
        for pais in country:
            url=f"https://ws.audioscrobbler.com/2.0/?method=geo.gettopartists&country={pais}&api_key={apikey}&format=json"
            respuesta=requests.get(url)
            respuesta.status_code

            if respuesta.status_code != 200:
                print(f"Error al consultar {country}: {respuesta.status_code}")
                continue
            
            info_top_artistas=respuesta.json()
            datos.append(info_top_artistas)


        return datos
    
    except Exception as e:
        print(f"Error: {e}")
        return []

# %%
ranking_top[0]
# Out:
# {'topartists': {'artist': [{'name': 'Bad Bunny',
#     'listeners': '12431',
#     'mbid': '89aa5ecb-59ad-46f5-b3eb-2d424e941f19',
#     'url': 'https://www.last.fm/music/Bad+Bunny',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '1'}},
#    {'name': 'ROSALÍA',
#     'listeners': '10254',
#     'mbid': '25f3abd9-63b5-471a-bd25-feb9672dfa11',
#     'url': 'https://www.last.fm/music/ROSAL%C3%8DA',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '2'}},
#    {'name': 'Quevedo',
#     'listeners': '8637',
#     'mbid': 'ef9bb29f-f466-4e28-8064-32558f4bb2df',
#     'url': 'https://www.last.fm/music/Quevedo',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '3'}},
#    {'name': 'Justin Bieber',
#     'listeners': '8379',
#     'mbid': 'e0140a67-e4d1-4f13-8a01-364355bee46e',
#     'url': 'https://www.last.fm/music/Justin+Bieber',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '4'}},
#    {'name': 'Olivia Rodrigo',
#     'listeners': '8227',
#     'mbid': '6925db17-f35e-42f3-a4eb-84ee6bf5d4b0',
#     'url': 'https://www.last.fm/music/Olivia+Rodrigo',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '5'}},
#    {'name': 'Taylor Swift',
#     'listeners': '8191',
#     'mbid': '20244d07-534f-4eff-b4d4-930878889970',
#     'url': 'https://www.last.fm/music/Taylor+Swift',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '6'}},
#    {'name': 'Bad Gyal',
#     'listeners': '7902',
#     'mbid': '9cb2e99f-d0ba-4aa5-a371-0006b0d34090',
#     'url': 'https://www.last.fm/music/Bad+Gyal',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '7'}},
#    {'name': 'Sabrina Carpenter',
#     'listeners': '7753',
#     'mbid': '1882fe91-cdd9-49c9-9956-8e06a3810bd4',
#     'url': 'https://www.last.fm/music/Sabrina+Carpenter',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '8'}},
#    {'name': 'Lady Gaga',
#     'listeners': '7663',
#     'mbid': '650e7db6-b795-4eb5-a702-5ea2fc46c848',
#     'url': 'https://www.last.fm/music/Lady+Gaga',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '9'}},
#    {'name': 'PinkPantheress',
#     'listeners': '7363',
#     'mbid': '7441014f-f8f5-494f-81db-ff166fbc078d',
#     'url': 'https://www.last.fm/music/PinkPantheress',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '10'}},
#    {'name': 'Charli xcx',
#     'listeners': '7343',
#     'mbid': '260b6184-8828-48eb-945c-bc4cb6fc34ca',
#     'url': 'https://www.last.fm/music/Charli+xcx',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '11'}},
#    {'name': 'Ariana Grande',
#     'listeners': '6952',
#     'mbid': 'f4fdbb4c-e4b7-47a0-b83b-d91bbfcfa387',
#     'url': 'https://www.last.fm/music/Ariana+Grande',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '12'}},
#    {'name': 'Rihanna',
#     'listeners': '6937',
#     'mbid': '73e5e69d-3554-40d8-8516-00cb38737a1c',
#     'url': 'https://www.last.fm/music/Rihanna',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '13'}},
#    {'name': 'Tame Impala',
#     'listeners': '6591',
#     'mbid': '63aa26c3-d59b-4da4-84ac-716b54f1ef4d',
#     'url': 'https://www.last.fm/music/Tame+Impala',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '14'}},
#    {'name': 'The Weeknd',
#     'listeners': '6376',
#     'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#     'url': 'https://www.last.fm/music/The+Weeknd',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '15'}},
#    {'name': 'Michael Jackson',
#     'listeners': '6233',
#     'mbid': 'f27ec8db-af05-4f36-916e-3d57f91ecf5e',
#     'url': 'https://www.last.fm/music/Michael+Jackson',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '16'}},
#    {'name': 'Rauw Alejandro',
#     'listeners': '6172',
#     'mbid': '197b70c7-8910-4030-ad03-632d82aa40e3',
#     'url': 'https://www.last.fm/music/Rauw+Alejandro',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '17'}},
#    {'name': 'Lana Del Rey',
#     'listeners': '6019',
#     'mbid': 'b7539c32-53e7-4908-bda3-81449c367da6',
#     'url': 'https://www.last.fm/music/Lana+Del+Rey',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '18'}},
#    {'name': 'Kanye West',
#     'listeners': '5964',
#     'url': 'https://www.last.fm/music/Kanye+West',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '19'}},
#    {'name': 'C. Tangana',
#     'listeners': '5960',
#     'mbid': '46d3689c-23e6-46f7-8ad6-c12f13ac9dea',
#     'url': 'https://www.last.fm/music/C.+Tangana',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '20'}},
#    {'name': 'Billie Eilish',
#     'listeners': '5880',
#     'mbid': 'f4abc0b5-3f7a-4eff-8f78-ac078dbce533',
#     'url': 'https://www.last.fm/music/Billie+Eilish',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '21'}},
#    {'name': 'Rusowsky',
#     'listeners': '5592',
#     'mbid': 'd836bdef-52ef-4142-baba-573e5b529478',
#     'url': 'https://www.last.fm/music/Rusowsky',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '22'}},
#    {'name': 'Radiohead',
#     'listeners': '5501',
#     'mbid': 'a74b1b7f-71a5-4011-9441-d0b5e4122711',
#     'url': 'https://www.last.fm/music/Radiohead',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '23'}},
#    {'name': 'Harry Styles',
#     'listeners': '5415',
#     'mbid': '7eb1ce54-a355-41f9-8d68-e018b096d427',
#     'url': 'https://www.last.fm/music/Harry+Styles',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '24'}},
#    {'name': 'Arctic Monkeys',
#     'listeners': '5232',
#     'mbid': 'ada7a83c-e3e1-40f1-93f9-3e73dbc9298a',
#     'url': 'https://www.last.fm/music/Arctic+Monkeys',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '25'}},
#    {'name': 'Bruno Mars',
#     'listeners': '5137',
#     'mbid': 'afb680f2-b6eb-4cd7-a70b-a63b25c763d5',
#     'url': 'https://www.last.fm/music/Bruno+Mars',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '26'}},
#    {'name': 'Aitana',
#     'listeners': '5025',
#     'mbid': 'a24f2bd3-0d1b-4c03-8d91-6297ab5a2811',
#     'url': 'https://www.last.fm/music/Aitana',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '27'}},
#    {'name': 'Shakira',
#     'listeners': '4999',
#     'mbid': 'bf24ca37-25f4-4e34-9aec-460b94364cfc',
#     'url': 'https://www.last.fm/music/Shakira',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '28'}},
#    {'name': 'Drake',
#     'listeners': '4979',
#     'mbid': '9fff2f8a-21e6-47de-a2b8-7f449929d43f',
#     'url': 'https://www.last.fm/music/Drake',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '29'}},
#    {'name': 'Madonna',
#     'listeners': '4962',
#     'mbid': '79239441-bfd5-4981-a70c-55c3f15c1287',
#     'url': 'https://www.last.fm/music/Madonna',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '30'}},
#    {'name': 'Omar Courtz',
#     'listeners': '4944',
#     'mbid': '61ee1029-4f35-43ce-83dd-2eb8d4eef85e',
#     'url': 'https://www.last.fm/music/Omar+Courtz',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '31'}},
#    {'name': 'Zara Larsson',
#     'listeners': '4870',
#     'mbid': '134e6410-6954-45d1-bd4a-0f2d2ad5471d',
#     'url': 'https://www.last.fm/music/Zara+Larsson',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '32'}},
#    {'name': 'Mora',
#     'listeners': '4808',
#     'mbid': '0f00e1ec-9702-45d8-82bd-1641268a968a',
#     'url': 'https://www.last.fm/music/Mora',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '33'}},
#    {'name': 'Katy Perry',
#     'listeners': '4757',
#     'mbid': '122d63fc-8671-43e4-9752-34e846d62a9c',
#     'url': 'https://www.last.fm/music/Katy+Perry',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '34'}},
#    {'name': 'Coldplay',
#     'listeners': '4671',
#     'mbid': 'cc197bad-dc9c-440d-a5b5-d52ba2e14234',
#     'url': 'https://www.last.fm/music/Coldplay',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '35'}},
#    {'name': 'RAYE',
#     'listeners': '4635',
#     'mbid': '8be564c3-dfba-440b-af8c-4ffbceeef45e',
#     'url': 'https://www.last.fm/music/RAYE',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '36'}},
#    {'name': 'Kendrick Lamar',
#     'listeners': '4621',
#     'mbid': '381086ea-f511-4aba-bdf9-71c753dc5077',
#     'url': 'https://www.last.fm/music/Kendrick+Lamar',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '37'}},
#    {'name': 'Myke Towers',
#     'listeners': '4592',
#     'mbid': 'd2945137-b01d-4195-9f82-64d20f8ba657',
#     'url': 'https://www.last.fm/music/Myke+Towers',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '38'}},
#    {'name': 'Gorillaz',
#     'listeners': '4535',
#     'mbid': 'e21857d5-3256-4547-afb3-4b6ded592596',
#     'url': 'https://www.last.fm/music/Gorillaz',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '39'}},
#    {'name': 'KAROL G',
#     'listeners': '4497',
#     'mbid': 'de22adae-f8ac-414f-b653-b0162611bd60',
#     'url': 'https://www.last.fm/music/KAROL+G',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '40'}},
#    {'name': 'The Strokes',
#     'listeners': '4484',
#     'mbid': 'f181961b-20f7-459e-89de-920ef03c7ed0',
#     'url': 'https://www.last.fm/music/The+Strokes',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '41'}},
#    {'name': 'David Guetta',
#     'listeners': '4457',
#     'mbid': '302bd7b9-d012-4360-897a-93b00c855680',
#     'url': 'https://www.last.fm/music/David+Guetta',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '42'}},
#    {'name': 'Bizarrap',
#     'listeners': '4440',
#     'mbid': '3b6abaef-febf-4cfe-943f-6a20cf0afdad',
#     'url': 'https://www.last.fm/music/Bizarrap',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '43'}},
#    {'name': 'Tyler, The Creator',
#     'listeners': '4437',
#     'mbid': 'f6beac20-5dfe-4d1f-ae02-0b0a740aafd6',
#     'url': 'https://www.last.fm/music/Tyler,+The+Creator',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '44'}},
#    {'name': 'Britney Spears',
#     'listeners': '4394',
#     'mbid': '45a663b5-b1cb-4a91-bff6-2bef7bbfdd76',
#     'url': 'https://www.last.fm/music/Britney+Spears',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '45'}},
#    {'name': 'Amaia',
#     'listeners': '4332',
#     'mbid': 'fd352180-b8c4-4ca3-a8e8-af21d2648372',
#     'url': 'https://www.last.fm/music/Amaia',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '46'}},
#    {'name': 'Chappell Roan',
#     'listeners': '4286',
#     'mbid': '56a55378-f155-48de-80a5-d80104221267',
#     'url': 'https://www.last.fm/music/Chappell+Roan',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '47'}},
#    {'name': 'BTS',
#     'listeners': '4280',
#     'mbid': '0d79fe8e-ba27-4859-bb8c-2f255f346853',
#     'url': 'https://www.last.fm/music/BTS',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '48'}},
#    {'name': 'Dua Lipa',
#     'listeners': '4278',
#     'mbid': '6f1a58bf-9b1b-49cf-a44a-6cefad7ae04f',
#     'url': 'https://www.last.fm/music/Dua+Lipa',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '49'}},
#    {'name': 'Linkin Park',
#     'listeners': '4269',
#     'mbid': 'f59c5520-5f46-4d2c-b2c4-822eabf53419',
#     'url': 'https://www.last.fm/music/Linkin+Park',
#     'streamable': '0',
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'mega'}],
#     '@attr': {'rank': '50'}}],
#   '@attr': {'country': 'Spain',
#    'page': '1',
#    'perPage': '50',
#    'totalPages': '46',
#    'total': '2253'}}}

# %% [markdown]
# #### Consulta final con resultados Pandas.

# %%
import requests
import pandas as pd

def consulta_top_artistas():
    """
    Consulta los top artistas por país usando la API de Last.fm.
    Retorna una lista de diccionarios con la respuesta JSON para cada país.
    """
    try:
        datos = []
        apikey = "48703fdebfcfe72db0d901a30cf4af31"
        # Lista de países (en el formato que espera la API)
        paises = ['spain', 'argentina', 'united states']
        
        for pais in paises:
            url = f"https://ws.audioscrobbler.com/2.0/?method=geo.gettopartists&country={pais}&api_key={apikey}&format=json"
            respuesta = requests.get(url)
            
            if respuesta.status_code != 200:
                print(f"Error al consultar {pais}: {respuesta.status_code}")
                continue
            
            info_top_artistas = respuesta.json()
            datos.append(info_top_artistas)
        
        return datos
    
    except Exception as e:
        print(f"Error general en consulta_top_artistas: {e}")
        return []

def construir_dataframe(datos_respuestas, nombres_paises):
    """
    Construye un DataFrame con las columnas 'pais', 'ranking', 'artista', 'oyentes'
    a partir de las respuestas de la API y los nombres de país correspondientes.
    """
    filas = []
    
    for nombre_pais, respuesta in zip(nombres_paises, datos_respuestas):
        # Extraer la lista de artistas (top 50)
        artistas = respuesta.get("topartists", {}).get("artist", [])
        
        for artista in artistas:
            # Extraer datos con valores por defecto seguros
            ranking = int(artista.get("@attr", {}).get("rank", 0))
            nombre_artista = artista.get("name", "Desconocido").title()
            oyentes = int(artista.get("listeners", "0"))
            
            filas.append({
                "pais": nombre_pais,
                "ranking": ranking,
                "artista": nombre_artista,
                "oyentes": oyentes
            })
    
    # Crear DataFrame y ordenar columnas
    df = pd.DataFrame(filas)
    return df[["pais", "ranking", "artista", "oyentes"]]

# ========== EJECUCIÓN PRINCIPAL ==========
if __name__ == "__main__":
    # 1. Obtener datos de la API
    respuestas = consulta_top_artistas()
    
    # 2. Nombres de países en el mismo orden que se usaron en la consulta
    paises = ["España", "Argentina", "Estados Unidos"]  
    
    # 3. Construir DataFrame
    df_top_artistas = construir_dataframe(respuestas, paises)
    
    # 4. Mostrar resultados
    print(df_top_artistas.head(10))  # primeras 10 filas
    print(f"\nTotal de registros: {len(df_top_artistas)}")
# Out:
#      pais  ranking            artista  oyentes
# 0  España        1          Bad Bunny    12431
# 1  España        2            Rosalía    10254
# 2  España        3            Quevedo     8637
# 3  España        4      Justin Bieber     8379
# 4  España        5     Olivia Rodrigo     8227
# 5  España        6       Taylor Swift     8191
# 6  España        7           Bad Gyal     7902
# 7  España        8  Sabrina Carpenter     7753
# 8  España        9          Lady Gaga     7663
# 9  España       10     Pinkpantheress     7363
#
# Total de registros: 150

# %%
df_top_artistas
# Out:
#                pais  ranking              artista  oyentes
# 0            España        1            Bad Bunny    12431
# 1            España        2              Rosalía    10254
# 2            España        3              Quevedo     8637
# 3            España        4        Justin Bieber     8379
# 4            España        5       Olivia Rodrigo     8227
# ..              ...      ...                  ...      ...
# 145  Estados Unidos       46              Tv Girl   125197
# 146  Estados Unidos       47           Steve Lacy   123631
# 147  Estados Unidos       48         Dominic Fike   121069
# 148  Estados Unidos       49  Panic! At The Disco   120877
# 149  Estados Unidos       50          The Strokes   120235
#
# [150 rows x 4 columns]

# %%
df_top_artistas.to_csv('top_artistas_esp_arg_usa.csv',index=False)
